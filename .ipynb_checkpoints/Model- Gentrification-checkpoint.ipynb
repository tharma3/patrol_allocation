# %%
import pandas as pd
import numpy as numpy
import json 
import os 
import pylab as pl
import urllib
import requests
import geopandas as gp
import fiona
import shapely
from fiona.crs import from_epsg
import os
import pandas as pd
import urllib
import requests
import json
import sys
import io
import shapely
import base64
import urllib.request
import functools
import geopandas as gp
import fiona
import numpy as np
import datetime


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
# %matplotlib inline

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## get gentrification indication data

# %%
path = '/Users/katharinevoorhees/Downloads/ACS_14_5YR_S1501/ACS_14_5YR_S1501_with_ann.csv'

fourteen = pd.read_csv(path, skiprows=1)

fourteen.rename(columns={"Total; Estimate; Percent bachelor's degree or higher":'%higher_ed_14',
                "Total; Estimate; MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2014 INFLATION-ADJUSTED DOLLARS) - Population 25 years and over with earnings":
                          'median_earnings_14'}, inplace=True)
fourteen = fourteen[['Id2', 'Geography', '%higher_ed_14','median_earnings_14']]
fourteen.head()
# Out:
#            Id2                                   Geography %higher_ed_14  \
# 0  36001000100     Census Tract 1, Albany County, New York          14.9
# 1  36001000200     Census Tract 2, Albany County, New York          10.2
# 2  36001000300     Census Tract 3, Albany County, New York          26.8
# 3  36001000401  Census Tract 4.01, Albany County, New York          43.9
# 4  36001000403  Census Tract 4.03, Albany County, New York          58.4
#
#   median_earnings_14
# 0              23974
# 1              31368
# 2              36024
# 3              49909
# 4              49840

# %%
path = '/Users/katharinevoorhees/Downloads/ACS_09_5YR_S1501/ACS_09_5YR_S1501_with_ann.csv'

ohnine = pd.read_csv(path, skiprows=1)

ohnine.rename(columns={"Total; Estimate; Population 25 years and over - Percent bachelor's degree or higher":'%higher_ed_09',
                "Total; Estimate; MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2009 INFLATION-ADJUSTED DOLLARS) - Population 25 years and over with earnings":
                          'median_earnings_09'}, inplace=True)
ohnine = ohnine[['Id2', 'Geography', '%higher_ed_09','median_earnings_09']]
ohnine.head()
# Out:
#            Id2                                   Geography %higher_ed_09  \
# 0  36001000100     Census Tract 1, Albany County, New York          11.0
# 1  36001000200     Census Tract 2, Albany County, New York          17.0
# 2  36001000300     Census Tract 3, Albany County, New York          22.7
# 3  36001000401  Census Tract 4.01, Albany County, New York          39.3
# 4  36001000403  Census Tract 4.03, Albany County, New York          51.5
#
#   median_earnings_09
# 0              35552
# 1              26051
# 2              33833
# 3              58869
# 4              45000

# %%
data = fourteen.merge(ohnine, on='Id2')
data.drop(columns=['Geography_y'], inplace=True)

# %%
data['%higher_ed_14'].replace('-',np.nan,inplace=True)
data['%higher_ed_09'].replace('-',np.nan,inplace=True)
data['median_earnings_14'].replace('-',np.nan,inplace=True)
data['median_earnings_09'].replace('-',np.nan,inplace=True)
data['median_earnings_09'].replace('2,500-',np.nan,inplace=True)



data.dropna(inplace=True)

data['%higher_ed_14'] = data['%higher_ed_14'].astype('float')
data['%higher_ed_09'] = data['%higher_ed_09'].astype('float')
data['median_earnings_14'] = data['median_earnings_14'].astype('float')
data['median_earnings_09'] = data['median_earnings_09'].astype('float')


data.sort_values('%higher_ed_14',ascending=False).head()
# Out:
#               Id2                                     Geography_x  \
# 3883  36109000400       Census Tract 4, Tompkins County, New York
# 2226  36061020701  Census Tract 207.01, New York County, New York
# 2038  36061002100      Census Tract 21, New York County, New York
# 2052  36061003300      Census Tract 33, New York County, New York
# 826   36047000700          Census Tract 7, Kings County, New York
#
#       %higher_ed_14  median_earnings_14  %higher_ed_09  median_earnings_09
# 3883           93.1             30737.0           63.5             22083.0
# 2226           91.4             38902.0           87.0             34298.0
# 2038           89.9            142148.0           83.4            130304.0
# 2052           89.8            104199.0           87.3            101623.0
# 826            89.6             80747.0           78.4             80032.0

# %%
len(data['median_earnings_09'])
# Out:
# 4146

# %%
data['%higher_ed_increase'] = data['%higher_ed_14'] - data['%higher_ed_09']
data['earnings_dif'] = data['median_earnings_14']-data['median_earnings_09']
data['%earnings_change'] = ((data['earnings_dif']/data['median_earnings_09'])*100)
data.head()
# Out:
#            Id2                                 Geography_x  %higher_ed_14  \
# 0  36001000100     Census Tract 1, Albany County, New York           14.9
# 1  36001000200     Census Tract 2, Albany County, New York           10.2
# 2  36001000300     Census Tract 3, Albany County, New York           26.8
# 3  36001000401  Census Tract 4.01, Albany County, New York           43.9
# 4  36001000403  Census Tract 4.03, Albany County, New York           58.4
#
#    median_earnings_14  %higher_ed_09  median_earnings_09  %higher_ed_increase  \
# 0             23974.0           11.0             35552.0                  3.9
# 1             31368.0           17.0             26051.0                 -6.8
# 2             36024.0           22.7             33833.0                  4.1
# 3             49909.0           39.3             58869.0                  4.6
# 4             49840.0           51.5             45000.0                  6.9
#
#    earnings_dif  %earnings_change
# 0      -11578.0        -32.566382
# 1        5317.0         20.409965
# 2        2191.0          6.475926
# 3       -8960.0        -15.220235
# 4        4840.0         10.755556

# %%
path = '/Users/katharinevoorhees/Downloads/ACS_14_5YR_B25077/ACS_14_5YR_B25077_with_ann.csv'

home14 = pd.read_csv(path, skiprows=1)

home14 = home14[['Id2','Estimate; Median value (dollars)']]
home14.rename(columns={'Estimate; Median value (dollars)':
                       'med_home_val_14'}, inplace=True)

home14.head()
# Out:
#            Id2 med_home_val_14
# 0  36001000100           94500
# 1  36001000200           85200
# 2  36001000300          175900
# 3  36001000401          154200
# 4  36001000403          193400

# %%
path = '/Users/katharinevoorhees/Downloads/ACS_09_5YR_B25077/ACS_09_5YR_B25077_with_ann.csv'

home09 = pd.read_csv(path, skiprows=1)

home09 = home09[['Id2','Estimate; Median value (dollars)']]
home09.rename(columns={'Estimate; Median value (dollars)':
                       'med_home_val_09'}, inplace=True)
home09.head()
# Out:
#            Id2 med_home_val_09
# 0  36001000100          112700
# 1  36001000200          131800
# 2  36001000300          127300
# 3  36001000401          163600
# 4  36001000403          203100

# %%
home_data = home09.merge(home14,on='Id2')
home_data.head()
# Out:
#            Id2 med_home_val_09 med_home_val_14
# 0  36001000100          112700           94500
# 1  36001000200          131800           85200
# 2  36001000300          127300          175900
# 3  36001000401          163600          154200
# 4  36001000403          203100          193400

# %%
home_data['med_home_val_09'].replace('1,000,000+',1000000,inplace=True)
home_data['med_home_val_14'].replace('1,000,000+',1000000,inplace=True)
home_data['med_home_val_09'].replace('-',np.nan, inplace=True)
home_data['med_home_val_14'].replace('-',np.nan, inplace=True)


home_data['med_home_val_09'] = home_data['med_home_val_09'].astype('float')
home_data['med_home_val_14'] = home_data['med_home_val_14'].astype('float')

# %%
home_data.dropna(inplace=True)
home_data['%home_increase'] = np.round(((home_data['med_home_val_14']-home_data['med_home_val_09'])/\
                               home_data['med_home_val_09'])*100,1)
home_data.head()
# Out:
#            Id2  med_home_val_09  med_home_val_14  %home_increase
# 0  36001000100         112700.0          94500.0           -16.1
# 1  36001000200         131800.0          85200.0           -35.4
# 2  36001000300         127300.0         175900.0            38.2
# 3  36001000401         163600.0         154200.0            -5.7
# 4  36001000403         203100.0         193400.0            -4.8

# %%
home_data.describe()
# Out:
#                 Id2  med_home_val_09  med_home_val_14  %home_increase
# count  4.003000e+03      4003.000000      4003.000000     4003.000000
# mean   3.606350e+10    384319.985011    378586.734949        3.722833
# std    3.089320e+07    244398.181959    242443.350615       47.513985
# min    3.600100e+10     12600.000000     14900.000000      -90.800000
# 25%    3.604703e+10    143850.000000    155450.000000       -9.900000
# 50%    3.606101e+10    397600.000000    368000.000000        0.000000
# 75%    3.608112e+10    548500.000000    520300.000000       10.550000
# max    3.611902e+10   1000000.000000   1000000.000000     1837.800000

# %%
path = '/Users/katharinevoorhees/Downloads/ACS_14_5YR_B02001/ACS_14_5YR_B02001_with_ann.csv'

race14 = pd.read_csv(path, skiprows=1)

race14 = race14.rename(columns={"Estimate; Total:":'tot14',
               'Estimate; Total: - White alone' :'wh14'})
race14['%white_14'] = (race14['wh14']/race14['tot14'])*100
race14 = race14[['Id2','wh14', '%white_14']]
race14.head()
# Out:
#            Id2  wh14  %white_14
# 0  36001000100   733  33.303044
# 1  36001000200   530  10.196229
# 2  36001000300  2503  45.352419
# 3  36001000401  2092  88.381918
# 4  36001000403  3249  70.969856

# %%
path = '/Users/katharinevoorhees/Downloads/ACS_09_5YR_B02001/ACS_09_5YR_B02001_with_ann.csv'

race09 = pd.read_csv(path, skiprows=1)

race09 = race09.rename(columns={"Estimate; Total:":'tot09',
               'Estimate; White alone' :'wh09'})
race09['%white_09'] = (race09['wh09']/race09['tot09'])*100
race09 = race09[['Id2','wh09', '%white_09']]
race09.head()
# Out:
#            Id2  wh09  %white_09
# 0  36001000100   700  32.543003
# 1  36001000200   602  11.982484
# 2  36001000300  3594  58.610568
# 3  36001000401  2025  92.677346
# 4  36001000403  3362  77.180900

# %%
race_data = race09.merge(race14, on='Id2')

race_data['%increase_white'] = race_data['%white_14'] - race_data['%white_09']

race_data.head()
# Out:
#            Id2  wh09  %white_09  wh14  %white_14  %increase_white
# 0  36001000100   700  32.543003   733  33.303044         0.760041
# 1  36001000200   602  11.982484   530  10.196229        -1.786255
# 2  36001000300  3594  58.610568  2503  45.352419       -13.258149
# 3  36001000401  2025  92.677346  2092  88.381918        -4.295427
# 4  36001000403  3362  77.180900  3249  70.969856        -6.211044

# %%
data = data.merge(home_data, how='left', on='Id2')
data = data.merge(race_data, how='left', on='Id2')

data = data[['Id2','%higher_ed_increase','%home_increase','%increase_white',"%earnings_change"]]

data.head()
# Out:
#            Id2  %higher_ed_increase  %home_increase  %increase_white  \
# 0  36001000100                  3.9           -16.1         0.760041
# 1  36001000200                 -6.8           -35.4        -1.786255
# 2  36001000300                  4.1            38.2       -13.258149
# 3  36001000401                  4.6            -5.7        -4.295427
# 4  36001000403                  6.9            -4.8        -6.211044
#
#    %earnings_change
# 0        -32.566382
# 1         20.409965
# 2          6.475926
# 3        -15.220235
# 4         10.755556

# %%
path= '/Users/katharinevoorhees/patrol_allocation/tract_precinct_key.csv'
prec_key = pd.read_csv(path)
prec_key = prec_key[['precinct','tractid']]
prec_key.head(3)
# Out:
#    precinct      tractid
# 0       1.0  36061004700
# 1       1.0  36061004900
# 2       1.0  36061003700

# %%
acs_data = prec_key.merge(data, left_on='tractid', right_on='Id2')
acs_data.head()
# Out:
#    precinct      tractid          Id2  %higher_ed_increase  %home_increase  \
# 0       1.0  36061004700  36061004700                  6.5             0.0
# 1       1.0  36061004900  36061004900                 -2.0             0.0
# 2       1.0  36061000900  36061000900                 -7.1            55.1
# 3       1.0  36061000700  36061000700                  1.8            -8.9
# 4       1.0  36061001300  36061001300                  2.9            -4.1
#
#    %increase_white  %earnings_change
# 0        -3.396385         -3.584302
# 1         0.946872         19.012517
# 2        18.743693         37.132999
# 3         6.428272        -12.865166
# 4         7.838132         13.498200

# %%
acs_data.shape
# Out:
# (1881, 7)

# %%
prec_key.shape
# Out:
# (2167, 2)

# %%
acs_data_grouped = acs_data.groupby('precinct').mean().reset_index()

acs_data_grouped.head()
# Out:
#    precinct       tractid           Id2  %higher_ed_increase  %home_increase  \
# 0       1.0  3.606100e+10  3.606100e+10             2.960000        7.870000
# 1       5.0  3.606100e+10  3.606100e+10             6.854545        7.030000
# 2       6.0  3.606101e+10  3.606101e+10             1.391667        3.558333
# 3       7.0  3.606100e+10  3.606100e+10             0.650000        5.612500
# 4       9.0  3.606100e+10  3.606100e+10             4.413333        1.200000
#
#    %increase_white  %earnings_change
# 0         0.457466         15.936095
# 1         4.543218         31.588472
# 2        -1.624774         15.786130
# 3        -1.897496         11.932918
# 4        -2.739962         27.541365

# %%
### ***add 311 noise  complaints

# %%
url = 'https://data.cityofnewyork.us/api/views/p5f6-bkga/rows.csv?accessType=DOWNLOAD'
complaint = pd.read_csv(url)
complaint.head()
# Out:
# /Users/katharinevoorhees/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unique Key            Created Date             Closed Date Agency  \
# 0    33935994  07/26/2016 06:28:38 AM  07/26/2016 10:28:29 AM   NYPD
# 1    33936000  07/27/2016 01:04:56 AM  07/27/2016 04:21:34 AM   NYPD
# 2    33936001  07/27/2016 01:11:43 AM  07/27/2016 08:30:15 AM   NYPD
# 3    33936005  07/27/2016 12:06:52 AM  07/27/2016 07:13:33 AM   NYPD
# 4    33936027  07/26/2016 07:31:23 AM  07/26/2016 09:44:07 AM   NYPD
#
#                        Agency Name           Complaint Type        Descriptor  \
# 0  New York City Police Department          Noise - Vehicle     Engine Idling
# 1  New York City Police Department       Noise - Commercial  Loud Music/Party
# 2  New York City Police Department      Noise - Residential      Loud Talking
# 3  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 4  New York City Police Department          Noise - Vehicle     Engine Idling
#
#                 Location Type  Incident Zip     Incident Address  \
# 0             Street/Sidewalk       10474.0  935 GARRISON AVENUE
# 1         Club/Bar/Restaurant       11433.0     92-06 173 STREET
# 2  Residential Building/House       11203.0  984 BROOKLYN AVENUE
# 3             Street/Sidewalk       11220.0        372 58 STREET
# 4             Street/Sidewalk       10002.0    133 EAST BROADWAY
#
#        Street Name                 Cross Street 1   Cross Street 2  \
# 0  GARRISON AVENUE                 TIFFANY STREET  BARRETTO STREET
# 1       173 STREET                 JAMAICA AVENUE        93 AVENUE
# 2  BROOKLYN AVENUE                  CHURCH AVENUE    SNYDER AVENUE
# 3        58 STREET  GOWANUS EXPWY EB EN BELT PKWY         4 AVENUE
# 4    EAST BROADWAY                    PIKE STREET   RUTGERS STREET
#
#   Intersection Street 1 Intersection Street 2 Address Type      City Landmark  \
# 0                   NaN                   NaN      ADDRESS     BRONX      NaN
# 1                   NaN                   NaN      ADDRESS   JAMAICA      NaN
# 2                   NaN                   NaN      ADDRESS  BROOKLYN      NaN
# 3                   NaN                   NaN      ADDRESS  BROOKLYN      NaN
# 4                   NaN                   NaN      ADDRESS  NEW YORK      NaN
#
#   Facility Type  Status                Due Date  \
# 0      Precinct  Closed  07/26/2016 02:28:38 PM
# 1      Precinct  Closed  07/27/2016 09:04:56 AM
# 2      Precinct  Closed  07/27/2016 09:11:43 AM
# 3      Precinct  Closed  07/27/2016 08:06:52 AM
# 4      Precinct  Closed  07/26/2016 03:31:23 PM
#
#                               Resolution Description  \
# 0  The Police Department responded to the complai...
# 1  The Police Department responded to the complai...
# 2  The Police Department responded to the complai...
# 3  The Police Department responded and upon arriv...
# 4  The Police Department responded to the complai...
#
#   Resolution Action Updated Date Community Board    Borough  \
# 0         07/26/2016 10:28:29 AM        02 BRONX      BRONX
# 1         07/27/2016 04:21:35 AM       12 QUEENS     QUEENS
# 2         07/27/2016 08:29:31 AM     17 BROOKLYN   BROOKLYN
# 3         07/27/2016 07:13:33 AM     07 BROOKLYN   BROOKLYN
# 4         07/26/2016 09:44:07 AM    03 MANHATTAN  MANHATTAN
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name  \
# 0                   1014358.0                    237287.0        Unspecified
# 1                   1043415.0                    197121.0        Unspecified
# 2                    999880.0                    176024.0        Unspecified
# 3                    979287.0                    173308.0        Unspecified
# 4                    986521.0                    199372.0        Unspecified
#
#   Park Borough  Vehicle Type  Taxi Company Borough  Taxi Pick Up Location  \
# 0        BRONX           NaN                   NaN                    NaN
# 1       QUEENS           NaN                   NaN                    NaN
# 2     BROOKLYN           NaN                   NaN                    NaN
# 3     BROOKLYN           NaN                   NaN                    NaN
# 4    MANHATTAN           NaN                   NaN                    NaN
#
#    Bridge Highway Name  Bridge Highway Direction  Road Ramp  \
# 0                  NaN                       NaN        NaN
# 1                  NaN                       NaN        NaN
# 2                  NaN                       NaN        NaN
# 3                  NaN                       NaN        NaN
# 4                  NaN                       NaN        NaN
#
#    Bridge Highway Segment   Latitude  Longitude  \
# 0                     NaN  40.817922 -73.891225
# 1                     NaN  40.707531 -73.786600
# 2                     NaN  40.649808 -73.943674
# 3                     NaN  40.642366 -74.017883
# 4                     NaN  40.713907 -73.991808
#
#                                   Location
# 0   (40.81792237097816, -73.8912245104243)
# 1  (40.70753055918456, -73.78659995072763)
# 2  (40.64980808783318, -73.94367355735429)
# 3  (40.64236565669747, -74.01788336131888)
# 4   (40.71390653618416, -73.9918080386684)

# %%
complaint['Created Date'] = pd.to_datetime(complaint['Created Date'])

# %%
complaint['year'] = complaint['Created Date'].dt.year
complaint.head(2)
# Out:
#    Unique Key        Created Date             Closed Date Agency  \
# 0    33935994 2016-07-26 06:28:38  07/26/2016 10:28:29 AM   NYPD
# 1    33936000 2016-07-27 01:04:56  07/27/2016 04:21:34 AM   NYPD
#
#                        Agency Name      Complaint Type        Descriptor  \
# 0  New York City Police Department     Noise - Vehicle     Engine Idling
# 1  New York City Police Department  Noise - Commercial  Loud Music/Party
#
#          Location Type  Incident Zip     Incident Address      Street Name  \
# 0      Street/Sidewalk       10474.0  935 GARRISON AVENUE  GARRISON AVENUE
# 1  Club/Bar/Restaurant       11433.0     92-06 173 STREET       173 STREET
#
#    Cross Street 1   Cross Street 2 Intersection Street 1  \
# 0  TIFFANY STREET  BARRETTO STREET                   NaN
# 1  JAMAICA AVENUE        93 AVENUE                   NaN
#
#   Intersection Street 2 Address Type     City Landmark Facility Type  Status  \
# 0                   NaN      ADDRESS    BRONX      NaN      Precinct  Closed
# 1                   NaN      ADDRESS  JAMAICA      NaN      Precinct  Closed
#
#                  Due Date                             Resolution Description  \
# 0  07/26/2016 02:28:38 PM  The Police Department responded to the complai...
# 1  07/27/2016 09:04:56 AM  The Police Department responded to the complai...
#
#   Resolution Action Updated Date Community Board Borough  \
# 0         07/26/2016 10:28:29 AM        02 BRONX   BRONX
# 1         07/27/2016 04:21:35 AM       12 QUEENS  QUEENS
#
#    X Coordinate (State Plane)  Y Coordinate (State Plane) Park Facility Name  \
# 0                   1014358.0                    237287.0        Unspecified
# 1                   1043415.0                    197121.0        Unspecified
#
#   Park Borough  Vehicle Type  Taxi Company Borough  Taxi Pick Up Location  \
# 0        BRONX           NaN                   NaN                    NaN
# 1       QUEENS           NaN                   NaN                    NaN
#
#    Bridge Highway Name  Bridge Highway Direction  Road Ramp  \
# 0                  NaN                       NaN        NaN
# 1                  NaN                       NaN        NaN
#
#    Bridge Highway Segment   Latitude  Longitude  \
# 0                     NaN  40.817922 -73.891225
# 1                     NaN  40.707531 -73.786600
#
#                                   Location  year
# 0   (40.81792237097816, -73.8912245104243)  2016
# 1  (40.70753055918456, -73.78659995072763)  2016

# %%
complaint['lonlat'] = list(zip(complaint.Longitude, complaint.Latitude))

# %%
complaint['geometry'] = complaint[['lonlat']].applymap(lambda x:shapely.geometry.Point(x))

# %%
complaint_map = gp.GeoDataFrame(complaint)

# %%
complaint_map.crs  = from_epsg(4326)

# %%
complaint_map.to_crs(epsg=2263, inplace=True)

# %%
complaint_map.plot();

# %%
url = 'https://data.cityofnewyork.us/api/geospatial/78dh-3ptz?method=export&format=Shapefile'
precinct = gp.GeoDataFrame.from_file(url)
precinct.plot();

# %%
precinct.to_crs(epsg=2263, inplace=True)

# %%
complaints_joined = gp.sjoin(precinct,complaint_map, how='right')
# Out:
# /Users/katharinevoorhees/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:2048: RuntimeWarning: invalid value encountered in ? (vectorized)
#   outputs = ufunc(*inputs)

# %%
complaints_joined.head()
# Out:
#              index_left  precinct    shape_area    shape_leng  Unique Key  \
# index_right
# 3039950             0.0       1.0  4.730176e+07  80586.154615    33889654
# 1081114             0.0       1.0  4.730176e+07  80586.154615    22283278
# 1102665             0.0       1.0  4.730176e+07  80586.154615    22533038
# 784652              0.0       1.0  4.730176e+07  80586.154615    16933639
# 2109450             0.0       1.0  4.730176e+07  80586.154615    26387705
#
#                    Created Date             Closed Date Agency  \
# index_right
# 3039950     2016-07-20 19:48:39  07/20/2016 11:19:03 PM   NYPD
# 1081114     2011-12-09 01:36:35  12/09/2011 01:54:56 AM   NYPD
# 1102665     2012-01-17 00:54:39  01/17/2012 01:24:01 AM   NYPD
# 784652      2010-06-24 11:26:38  06/24/2010 12:27:37 PM   NYPD
# 2109450     2013-09-26 09:51:00  10/01/2013 03:45:00 PM    DEP
#
#                                         Agency Name       Complaint Type  \
# index_right
# 3039950             New York City Police Department      Noise - Vehicle
# 1081114             New York City Police Department   Noise - Commercial
# 1102665             New York City Police Department      Noise - Vehicle
# 784652              New York City Police Department  Noise - Residential
# 2109450      Department of Environmental Protection                Noise
#
#                                       Descriptor               Location Type  \
# index_right
# 3039950                            Engine Idling             Street/Sidewalk
# 1081114                             Loud Talking         Club/Bar/Restaurant
# 1102665                          Car/Truck Music             Street/Sidewalk
# 784652                          Banging/Pounding  Residential Building/House
# 2109450      Noise: Construction Equipment (NC1)                         NaN
#
#              Incident Zip         Incident Address          Street Name  \
# index_right
# 3039950           10014.0                      NaN                  NaN
# 1081114           10012.0      WEST HOUSTON STREET  WEST HOUSTON STREET
# 1102665           10012.0      WEST HOUSTON STREET  WEST HOUSTON STREET
# 784652            10014.0  273 WEST HOUSTON STREET  WEST HOUSTON STREET
# 2109450           10013.0     34 DESBROSSES STREET    DESBROSSES STREET
#
#             Cross Street 1    Cross Street 2 Intersection Street 1  \
# index_right
# 3039950                NaN               NaN   WEST HOUSTON STREET
# 1081114      WEST BROADWAY   THOMPSON STREET                   NaN
# 1102665      WEST BROADWAY   THOMPSON STREET                   NaN
# 784652       VARICK STREET     HUDSON STREET                   NaN
# 2109450      WASHINGTON ST  JOE DIMAGGIO HWY                   NaN
#
#             Intersection Street 2  Address Type      City Landmark  \
# index_right
# 3039950          GREENWICH STREET  INTERSECTION  NEW YORK      NaN
# 1081114                       NaN     BLOCKFACE  NEW YORK      NaN
# 1102665                       NaN     BLOCKFACE  NEW YORK      NaN
# 784652                        NaN       ADDRESS  NEW YORK      NaN
# 2109450                       NaN       ADDRESS  NEW YORK      NaN
#
#             Facility Type  Status                Due Date  \
# index_right
# 3039950          Precinct  Closed  07/21/2016 03:48:39 AM
# 1081114          Precinct  Closed  12/09/2011 09:36:35 AM
# 1102665          Precinct  Closed  01/17/2012 08:54:39 AM
# 784652           Precinct  Closed  06/24/2010 07:26:38 PM
# 2109450               NaN  Closed                     NaN
#
#                                         Resolution Description  \
# index_right
# 3039950      The Police Department responded and upon arriv...
# 1081114      The Police Department responded and upon arriv...
# 1102665      The Police Department responded to the complai...
# 784652                                                     NaN
# 2109450      The Department of Environmental Protection did...
#
#             Resolution Action Updated Date Community Board    Borough  \
# index_right
# 3039950             07/20/2016 11:19:03 PM    02 MANHATTAN  MANHATTAN
# 1081114             12/09/2011 01:54:56 AM    02 MANHATTAN  MANHATTAN
# 1102665             01/17/2012 01:24:01 AM    02 MANHATTAN  MANHATTAN
# 784652              06/24/2010 12:00:00 AM    02 MANHATTAN  MANHATTAN
# 2109450             10/01/2013 03:45:00 PM    01 MANHATTAN  MANHATTAN
#
#              X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# index_right
# 3039950                        981868.0                    204840.0
# 1081114                        984174.0                    204182.0
# 1102665                        984174.0                    204182.0
# 784652                         982358.0                    204776.0
# 2109450                        981316.0                    202884.0
#
#             Park Facility Name Park Borough  Vehicle Type  \
# index_right
# 3039950            Unspecified    MANHATTAN           NaN
# 1081114            Unspecified    MANHATTAN           NaN
# 1102665            Unspecified    MANHATTAN           NaN
# 784652             Unspecified    MANHATTAN           NaN
# 2109450            Unspecified    MANHATTAN           NaN
#
#              Taxi Company Borough  Taxi Pick Up Location  Bridge Highway Name  \
# index_right
# 3039950                       NaN                    NaN                  NaN
# 1081114                       NaN                    NaN                  NaN
# 1102665                       NaN                    NaN                  NaN
# 784652                        NaN                    NaN                  NaN
# 2109450                       NaN                    NaN                  NaN
#
#              Bridge Highway Direction  Road Ramp  Bridge Highway Segment  \
# index_right
# 3039950                           NaN        NaN                     NaN
# 1081114                           NaN        NaN                     NaN
# 1102665                           NaN        NaN                     NaN
# 784652                            NaN        NaN                     NaN
# 2109450                           NaN        NaN                     NaN
#
#               Latitude  Longitude                                 Location  \
# index_right
# 3039950      40.728915 -74.008594  (40.72891484689489, -74.00859429619469)
# 1081114      40.727109 -74.000274  (40.72710911775691, -74.00027420185187)
# 1102665      40.727109 -74.000274  (40.72710911775691, -74.00027420185187)
# 784652       40.728739 -74.006826  (40.72873930090335, -74.00682634993956)
# 2109450      40.723546 -74.010585  (40.72354593675196, -74.01058506870447)
#
#              year                                   lonlat  \
# index_right
# 3039950      2016  (-74.00859429619469, 40.72891484689489)
# 1081114      2011   (-74.00027420185188, 40.7271091177569)
# 1102665      2012   (-74.00027420185188, 40.7271091177569)
# 784652       2010  (-74.00682634993957, 40.72873930090336)
# 2109450      2013  (-74.01058506870447, 40.72354593675196)
#
#                                                 geometry
# index_right
# 3039950      POINT (981868.0000014125 204840.0144054297)
# 1081114      POINT (984174.0000000411 204182.0144049953)
# 1102665      POINT (984174.0000000411 204182.0144049953)
# 784652       POINT (982358.0000011192 204776.0144053839)
# 2109450      POINT (981316.0000017417 202884.0144041627)

# %%
grouped_complaints = complaints_joined.groupby(['precinct','year']).count().reset_index()
complaint_2010 = grouped_complaints[grouped_complaints['year'] == 2010] 
complaint_2014 = grouped_complaints[grouped_complaints['year'] == 2014]
complaint_2010.rename(columns={'index_left':'count_10'},inplace=True)
complaint_2014.rename(columns={'index_left':'count_14'},inplace=True)
complaint_data = complaint_2010.merge(complaint_2014, on='precinct')
complaint_data = complaint_data[['precinct','count_10','count_14']]
complaint_data.head()
# Out:
# /Users/katharinevoorhees/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#    precinct  count_10  count_14
# 0       1.0      2812      5529
# 1       5.0      1836      3060
# 2       6.0      3168      4803
# 3       7.0      1937      3491
# 4       9.0      4468      7060

# %%
complaint_data.to_csv('noise_complaints_aggregated.csv')

# %%
complaint_data['%change_noise'] = ((complaint_data['count_14'] - complaint_data['count_10'])/\
                                complaint_data['count_10'])*100

complaint_data.describe()
# Out:
#          precinct     count_10      count_14  %change_noise
# count   77.000000    77.000000     77.000000      77.000000
# mean    63.324675  2609.493506   4375.363636      68.979988
# std     36.118388  1185.439599   2176.076230      30.507648
# min      1.000000   212.000000    444.000000       7.274360
# 25%     32.000000  1858.000000   2956.000000      51.473272
# 50%     66.000000  2290.000000   3915.000000      71.055684
# 75%    100.000000  3368.000000   5529.000000      83.113069
# max    123.000000  5765.000000  12913.000000     149.622879

# %% [markdown]
# ## get gentrification score

# %%
gent = complaint_data.merge(acs_data_grouped,on='precinct')
gent.head()
# Out:
#    precinct  count_10  count_14  %change_noise       tractid           Id2  \
# 0       1.0      2812      5529      96.621622  3.606100e+10  3.606100e+10
# 1       5.0      1836      3060      66.666667  3.606100e+10  3.606100e+10
# 2       6.0      3168      4803      51.609848  3.606101e+10  3.606101e+10
# 3       7.0      1937      3491      80.227155  3.606100e+10  3.606100e+10
# 4       9.0      4468      7060      58.012534  3.606100e+10  3.606100e+10
#
#    %higher_ed_increase  %home_increase  %increase_white  %earnings_change
# 0             2.960000        7.870000         0.457466         15.936095
# 1             6.854545        7.030000         4.543218         31.588472
# 2             1.391667        3.558333        -1.624774         15.786130
# 3             0.650000        5.612500        -1.897496         11.932918
# 4             4.413333        1.200000        -2.739962         27.541365

# %%
gent['city_noise'] = gent['%change_noise']/gent['%change_noise'].sum()
gent['city_edu'] = gent['%higher_ed_increase']/gent['%higher_ed_increase'].sum()
gent['city_home'] = gent['%home_increase']/gent['%home_increase'].sum()
gent['city_white'] = gent['%increase_white']/gent['%increase_white'].sum()
gent['city_earnings'] = gent['%earnings_change']/gent['%earnings_change'].sum()
gent.head()
# Out:
#    precinct  count_10  count_14  %change_noise       tractid           Id2  \
# 0       1.0      2812      5529      96.621622  3.606100e+10  3.606100e+10
# 1       5.0      1836      3060      66.666667  3.606100e+10  3.606100e+10
# 2       6.0      3168      4803      51.609848  3.606101e+10  3.606101e+10
# 3       7.0      1937      3491      80.227155  3.606100e+10  3.606100e+10
# 4       9.0      4468      7060      58.012534  3.606100e+10  3.606100e+10
#
#    %higher_ed_increase  %home_increase  %increase_white  %earnings_change  \
# 0             2.960000        7.870000         0.457466         15.936095
# 1             6.854545        7.030000         4.543218         31.588472
# 2             1.391667        3.558333        -1.624774         15.786130
# 3             0.650000        5.612500        -1.897496         11.932918
# 4             4.413333        1.200000        -2.739962         27.541365
#
#    city_noise  city_edu  city_home  city_white  city_earnings
# 0    0.018574  0.013820   0.010118   -0.008150       0.020202
# 1    0.012816  0.032004   0.009038   -0.080940       0.040044
# 2    0.009921  0.006498   0.004575    0.028946       0.020011
# 3    0.015422  0.003035   0.007216    0.033805       0.015127
# 4    0.011152  0.020606   0.001543    0.048814       0.034913

# %%
#gent['city_noise']

gent['gent_total'] = gent['city_noise']+gent['city_edu']+gent['city_home']+gent['city_white']+gent['city_earnings']

# %%
gent['gent_rate'] = gent['gent_total']/gent['gent_total'].sum()
gent.head()
# Out:
#    precinct  count_10  count_14  %change_noise       tractid           Id2  \
# 0       1.0      2812      5529      96.621622  3.606100e+10  3.606100e+10
# 1       5.0      1836      3060      66.666667  3.606100e+10  3.606100e+10
# 2       6.0      3168      4803      51.609848  3.606101e+10  3.606101e+10
# 3       7.0      1937      3491      80.227155  3.606100e+10  3.606100e+10
# 4       9.0      4468      7060      58.012534  3.606100e+10  3.606100e+10
#
#    %higher_ed_increase  %home_increase  %increase_white  %earnings_change  \
# 0             2.960000        7.870000         0.457466         15.936095
# 1             6.854545        7.030000         4.543218         31.588472
# 2             1.391667        3.558333        -1.624774         15.786130
# 3             0.650000        5.612500        -1.897496         11.932918
# 4             4.413333        1.200000        -2.739962         27.541365
#
#    city_noise  city_edu  city_home  city_white  city_earnings  gent_total  \
# 0    0.018574  0.013820   0.010118   -0.008150       0.020202    0.054564
# 1    0.012816  0.032004   0.009038   -0.080940       0.040044    0.012962
# 2    0.009921  0.006498   0.004575    0.028946       0.020011    0.069951
# 3    0.015422  0.003035   0.007216    0.033805       0.015127    0.074605
# 4    0.011152  0.020606   0.001543    0.048814       0.034913    0.117028
#
#    gent_rate
# 0   0.010913
# 1   0.002592
# 2   0.013990
# 3   0.014921
# 4   0.023406

# %% [markdown]
# ##  Felony arrests - data download/aggregation

# %%
url = 'https://data.cityofnewyork.us/api/views/8h9b-rp9u/rows.csv?accessType=DOWNLOAD'
arrests = pd.read_csv(url)

# %%
arrests['year'] = arrests['ARREST_DATE'].str[-2:]

arrests_ouryrs = arrests[(arrests['year'] == '09') | (arrests['year'] == '14')]

arrests_2009 = arrests[arrests['year'] == '09']
arrests_2014 = arrests[arrests['year'] == '14']

# %%
arrests_2009 = arrests_2009[arrests_2009['LAW_CAT_CD'] == 'F']
arrests_2014 = arrests_2014[arrests_2014['LAW_CAT_CD'] == 'F']

# %%
grouped09 = arrests_2009.groupby('ARREST_PRECINCT').count().reset_index()
grouped14 = arrests_2014.groupby('ARREST_PRECINCT').count().reset_index()

grouped09 = grouped09[['ARREST_PRECINCT','ARREST_KEY']]
grouped14 = grouped14[['ARREST_PRECINCT','ARREST_KEY']]

grouped09.rename(columns={'ARREST_KEY':'felony_09'}, inplace=True)
grouped14.rename(columns={'ARREST_KEY':'felony_14'}, inplace=True)

# %%
felony_arrest = grouped09.merge(grouped14, on='ARREST_PRECINCT')

# %%
felony_arrest.head()

# %%
felony_arrest['%city_14'] = felony_arrest['felony_14']/(felony_arrest['felony_14'].sum())
felony_arrest.head()
# Out:
#    ARREST_PRECINCT  felony_09  felony_14  %city_14
# 0                1        728        691  0.007388
# 1                5       1983       2075  0.022186
# 2                6       1059        896  0.009580
# 3                7        859        830  0.008875
# 4                9       1214        932  0.009965

# %%
felony_arrest.sort_values('%city_14',ascending=False).head(3)
# Out:
#     ARREST_PRECINCT  felony_09  felony_14  %city_14
# 46               75       3588       3824  0.040887
# 45               73       2312       2652  0.028356
# 26               44       3290       2576  0.027543

# %%
felony_arrest.to_csv('felonies_09_14.csv')

# %%
felony = pd.read_csv('felonies_09_14.csv')

# %%
felony.head()
# Out:
#    Unnamed: 0  ARREST_PRECINCT  felony_09  felony_14
# 0           0                1        728        691
# 1           1                5       1983       2075
# 2           2                6       1059        896
# 3           3                7        859        830
# 4           4                9       1214        932

# %%
felony['city_14'] = felony['felony_14']/felony['felony_14'].sum()

# %% [markdown]
# ## model calc

# %%
model_data = gent.merge(felony, left_on='precinct',right_on='ARREST_PRECINCT')
model_data = model_data[['precinct','city_14','gent_rate']]
model_data.head()
# Out:
#    precinct   city_14  gent_rate
# 0       1.0  0.007388   0.010913
# 1       5.0  0.022186   0.002592
# 2       6.0  0.009580   0.013990
# 3       7.0  0.008875   0.014921
# 4       9.0  0.009965   0.023406

# %%
model_data['total'] = model_data['city_14'] + model_data['gent_rate']
model_data['model_rate'] = model_data['total']/model_data['total'].sum()
model_data['MODEL_allocation'] = np.round(model_data['model_rate']*20000)

model_data.head()
# Out:
#    precinct   city_14  gent_rate     total  model_rate  MODEL_allocation
# 0       1.0  0.007388   0.010913  0.018301    0.009171             183.0
# 1       5.0  0.022186   0.002592  0.024779    0.012417             248.0
# 2       6.0  0.009580   0.013990  0.023571    0.011811             236.0
# 3       7.0  0.008875   0.014921  0.023795    0.011924             238.0
# 4       9.0  0.009965   0.023406  0.033371    0.016722             334.0

# %%
model_data.sort_values('gent_rate', ascending=False)
# Out:
#     precinct   city_14  gent_rate     total  model_rate  MODEL_allocation
# 31      50.0  0.005325   0.047214  0.052539    0.026328             527.0
# 43      72.0  0.010286   0.044095  0.054381    0.027251             545.0
# 55      94.0  0.004886   0.040205  0.045092    0.022596             452.0
# 21      40.0  0.026314   0.040138  0.066452    0.033300             666.0
# 65     109.0  0.015162   0.039921  0.055082    0.027602             552.0
# 35      62.0  0.009131   0.039669  0.048800    0.024454             489.0
# 52      84.0  0.013483   0.038517  0.052000    0.026058             521.0
# 67     111.0  0.004117   0.037180  0.041296    0.020694             414.0
# 26      45.0  0.007485   0.034289  0.041774    0.020933             419.0
# 15      26.0  0.006137   0.033457  0.039594    0.019841             397.0
# 9       18.0  0.014670   0.033240  0.047910    0.024008             480.0
# 5       10.0  0.007121   0.031969  0.039090    0.019588             392.0
# 56     100.0  0.006736   0.031766  0.038502    0.019294             386.0
# 6       13.0  0.011569   0.030039  0.041608    0.020850             417.0
# 54      90.0  0.010564   0.029274  0.039838    0.019963             399.0
# 39      68.0  0.006683   0.028778  0.035461    0.017770             355.0
# 22      41.0  0.025020   0.028281  0.053300    0.026709             534.0
# 64     108.0  0.006768   0.027748  0.034516    0.017296             346.0
# 41      70.0  0.013911   0.025474  0.039384    0.019736             395.0
# 8       17.0  0.003625   0.024561  0.028186    0.014124             282.0
# 36      63.0  0.008105   0.024167  0.032272    0.016172             323.0
# 7       14.0  0.021908   0.023581  0.045489    0.022795             456.0
# 4        9.0  0.009965   0.023406  0.033371    0.016722             334.0
# 37      66.0  0.006030   0.021336  0.027366    0.013713             274.0
# 32      52.0  0.021427   0.019341  0.040769    0.020430             409.0
# 66     110.0  0.011195   0.018521  0.029716    0.014891             298.0
# 33      60.0  0.013408   0.016551  0.029960    0.015013             300.0
# 30      49.0  0.009142   0.016518  0.025660    0.012858             257.0
# 34      61.0  0.011077   0.016263  0.027340    0.013701             274.0
# 40      69.0  0.010190   0.016178  0.026368    0.013213             264.0
# 70     114.0  0.016744   0.015091  0.031835    0.015953             319.0
# 3        7.0  0.008875   0.014921  0.023795    0.011924             238.0
# 2        6.0  0.009580   0.013990  0.023571    0.011811             236.0
# 58     102.0  0.015857   0.013927  0.029783    0.014925             298.0
# 73     122.0  0.007388   0.013287  0.020675    0.010361             207.0
# 71     115.0  0.017193   0.012742  0.029935    0.015001             300.0
# 60     104.0  0.010970   0.012406  0.023377    0.011714             234.0
# 20      34.0  0.009495   0.012400  0.021895    0.010972             219.0
# 13      24.0  0.006373   0.011995  0.018368    0.009204             184.0
# 62     106.0  0.012767   0.011863  0.024629    0.012342             247.0
# 10      19.0  0.008212   0.011665  0.019876    0.009960             199.0
# 46      76.0  0.004886   0.011564  0.016450    0.008243             165.0
# 0        1.0  0.007388   0.010913  0.018301    0.009171             183.0
# 61     105.0  0.019332   0.008880  0.028212    0.014137             283.0
# 38      67.0  0.022411   0.008666  0.031077    0.015573             311.0
# 63     107.0  0.008233   0.008363  0.016596    0.008316             166.0
# 28      47.0  0.018016   0.007879  0.025896    0.012977             260.0
# 12      23.0  0.011537   0.007705  0.019242    0.009642             193.0
# 23      42.0  0.016445   0.007222  0.023667    0.011860             237.0
# 68     112.0  0.005870   0.007065  0.012935    0.006482             130.0
# 74     123.0  0.004769   0.007059  0.011827    0.005927             119.0
# 44      73.0  0.028356   0.006831  0.035187    0.017632             353.0
# 48      78.0  0.005015   0.006511  0.011526    0.005776             116.0
# 11      20.0  0.004298   0.004614  0.008912    0.004466              89.0
# 27      46.0  0.024667   0.004570  0.029237    0.014651             293.0
# 14      25.0  0.020112   0.004548  0.024660    0.012357             247.0
# 47      77.0  0.017963   0.004455  0.022418    0.011234             225.0
# 72     120.0  0.016765   0.002908  0.019673    0.009858             197.0
# 1        5.0  0.022186   0.002592  0.024779    0.012417             248.0
# 59     103.0  0.023951  -0.000095  0.023856    0.011954             239.0
# 69     113.0  0.026741  -0.000187  0.026554    0.013306             266.0
# 17      30.0  0.008329  -0.000704  0.007625    0.003821              76.0
# 19      33.0  0.010425  -0.001056  0.009369    0.004695              94.0
# 18      32.0  0.011676  -0.002608  0.009068    0.004544              91.0
# 29      48.0  0.020251  -0.002652  0.017599    0.008819             176.0
# 16      28.0  0.012285  -0.003090  0.009195    0.004608              92.0
# 49      79.0  0.018326  -0.006922  0.011405    0.005715             114.0
# 42      71.0  0.014360  -0.007395  0.006965    0.003490              70.0
# 57     101.0  0.011173  -0.010235  0.000938    0.000470               9.0
# 53      88.0  0.008180  -0.010907 -0.002728   -0.001367             -27.0
# 25      44.0  0.027543  -0.013117  0.014426    0.007229             145.0
# 50      81.0  0.015546  -0.013788  0.001759    0.000881              18.0
# 24      43.0  0.020636  -0.019101  0.001535    0.000769              15.0
# 45      75.0  0.040887  -0.019166  0.021721    0.010885             218.0
# 51      83.0  0.016102  -0.041269 -0.025166   -0.012611            -252.0

# %%
model_data.to_csv('gentrification_model_results.csv')

# %%
url = 'https://data.cityofnewyork.us/api/geospatial/78dh-3ptz?method=export&format=Shapefile'
precinct = gp.GeoDataFrame.from_file(url)
precinct.head(2)
# Out:
#    precinct    shape_area    shape_leng  \
# 0       1.0  4.730176e+07  80586.154615
# 1       5.0  1.808880e+07  18676.124259
#
#                                             geometry
# 0  (POLYGON ((-74.0438776157395 40.69018767637665...
# 1  POLYGON ((-73.98863862848766 40.72293372026369...

# %%
#join to model data

precinct = precinct.merge(model_data, on='precinct', how='left')

precinct.shape
# Out:
# (77, 9)

# %%
precinct.replace(np.nan,0,inplace=True)

nan = precinct[precinct['MODEL_allocation'].isnull()]
nan
# Out:
# Empty GeoDataFrame
# Columns: [precinct, shape_area, shape_leng, geometry, city_14, gent_rate, total, model_rate, MODEL_allocation]
# Index: []

# %%
precinct.to_crs(epsg=2263, inplace=True)
precinct.crs
# Out:
# {'init': 'epsg:2263', 'no_defs': True}

# %%
#make cloropleth of precincts shaded by allocation in this model 

f,ax = plt.subplots(figsize=(10,10))
precinct.plot(column='MODEL_allocation', cmap="Blues", edgecolor="grey",ax=ax,
              scheme='quantiles',k=6, lw=.5, legend=True)
ax.axis('off')
plt.title('Violent Crime Model' ,fontsize=(20))

leg = ax.get_legend()
leg.set_bbox_to_anchor((0,-.08,.25,1));
# Out:
# /Users/katharinevoorhees/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
